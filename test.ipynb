# %%
import torch
import torch.nn as nn

# %%
w = torch.tensor((1,2))

# %%
w.shape
# Out:
# torch.Size([2])

# %%
w
# Out:
# tensor([1, 2])

# %%
w1 = torch.empty((1, 2))
w1.shape
# Out:
# torch.Size([1, 2])

# %%
w1
# Out:
# tensor([[0., 0.]])

# %%
b = torch.tensor(3)
print(b)
b.shape
# Out:
# tensor(3)
# torch.Size([])

# %%
b1 = torch.empty(2)
b1
# Out:
# tensor([2.8026e-45, 0.0000e+00])

# %%
nn.init.uniform_(b1)
# Out:
# tensor([0.8406, 0.0451])
